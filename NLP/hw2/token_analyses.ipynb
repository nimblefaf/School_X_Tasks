# %% [markdown]
# Д.З.: Выбираем писателя (без повторений), желательно русского, желательно из золотого или серебряного века, желательно не поэта
# Взять 6 произведений из разных этапов его жизни и проанализировть его (к примеру, на лексическое разнообразие, на количество тех или иных частей речи)
#
# Выполнить исследование творчества выбранного писателя по произведениям разных периодов его жизни (не менее 6 произведений). Сделать вывод о том, как менялось творчество писателя по мере его становления.

# %%
## Импорт библиотеки, загрузка моделей и словаря wordnet
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text1_pereval_1958 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Перевал (1958).txt'
with open(path) as f:
    text1_pereval_1958 = ' '.join(f.readlines())
print(len(text1_pereval_1958))


text2_starodub_1960 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Стародуб (1960).txt'
with open(path, encoding='utf-8') as f:
    text2_starodub_1960 = ' '.join(f.readlines())
print(len(text2_starodub_1960))


text3_kraja_1966 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Кража (1966).txt'
with open(path) as f:
    text3_kraja_1966 = ' '.join(f.readlines())
print(len(text3_kraja_1966))


text4_tsar_riba_1976 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Царь-рыба (1976).txt'
with open(path) as f:
    text4_tsar_riba_1976 = ' '.join(f.readlines())
print(len(text4_tsar_riba_1976))



text5_tak_hochetsa_jit_1995 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Так хочется жить (1995).txt'
with open(path) as f:
    text5_tak_hochetsa_jit_1995 = ' '.join(f.readlines())
print(len(text5_tak_hochetsa_jit_1995))


text6_veselii_soldat_1998 = ''
path = 'C:\\Users\\user\\Desktop\\DeepAutomation\\NLP\\Texts\\В. Астафьев. Весёлый солдат (1998).txt'
with open(path, encoding='utf-8') as f:
    text6_veselii_soldat_1998 = ' '.join(f.readlines())
print(len(text6_veselii_soldat_1998))
# Out:
# 201071
# 139850
# 456586
# 181426
# 398917
# 539050

# %%
text = text1_pereval_1958
tokenized = nltk.word_tokenize(text)
tokenized
# Out:
# ['Виктор',
#  'Петрович',
#  'Астафьев',
#  'Перевал',
#  'Светлой',
#  'памяти',
#  'матери',
#  'моей',
#  'Лидии',
#  'Ильиничны',
#  'Далекий',
#  'поселок',
#  'По',
#  'всей',
#  'стране',
#  'стучали',
#  'звонко',
#  'топоры',
#  '.',
#  'Россия',
#  'строилась',
#  'и',
#  'обновлялась',
#  '.',
#  'В',
#  'большом',
#  'сибирском',
#  'городе',
#  ',',
#  'чуть',
#  'повыше',
#  'старого',
#  'железнодорожного',
#  'моста',
#  ',',
#  'на',
#  'берегу',
#  'Енисея',
#  ',',
#  'как-то',
#  'разом',
#  ',',
#  'вдруг',
#  'поднялась',
#  'тощая',
#  'труба',
#  'с',
#  'искрогасителем',
#  'и',
#  'начала',
#  'обильно',
#  'окуривать',
#  'небо',
#  'едучим',
#  'опилочным',
#  'дымом',
#  ',',
#  'здесь',
#  'воздвигался',
#  'и',
#  'быстро',
#  'рос',
#  'деревообделочный',
#  'комбинат',
#  '—',
#  'сокращенно',
#  'ДОК',
#  '.',
#  'Само',
#  'собой',
#  ',',
#  'комбинату',
#  ',',
#  'да',
#  'еще',
#  'деревообделочному',
#  ',',
#  'требовался',
#  'и',
# ...

# %%
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('Виктор', 'JJ'),
#  ('Петрович', 'NNP'),
#  ('Астафьев', 'NNP'),
#  ('Перевал', 'NNP'),
#  ('Светлой', 'NNP'),
#  ('памяти', 'NNP'),
#  ('матери', 'NNP'),
#  ('моей', 'NNP'),
#  ('Лидии', 'NNP'),
#  ('Ильиничны', 'NNP'),
#  ('Далекий', 'NNP'),
#  ('поселок', 'NNP'),
#  ('По', 'NNP'),
#  ('всей', 'NNP'),
#  ('стране', 'NNP'),
#  ('стучали', 'NNP'),
#  ('звонко', 'NNP'),
#  ('топоры', 'NNP'),
#  ('.', '.'),
#  ('Россия', 'VB'),
#  ('строилась', 'JJ'),
#  ('и', 'NNP'),
#  ('обновлялась', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('большом', 'JJ'),
#  ('сибирском', 'NNP'),
#  ('городе', 'NNP'),
#  (',', ','),
#  ('чуть', 'NNP'),
#  ('повыше', 'NNP'),
#  ('старого', 'NNP'),
#  ('железнодорожного', 'NNP'),
#  ('моста', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('берегу', 'NNP'),
#  ('Енисея', 'NNP'),
#  (',', ','),
#  ('как-то', 'JJ'),
#  ('разом', 'NN'),
#  (',', ','),
#  ('вдруг', 'NNP'),
#  ('поднялась', 'NNP'),
#  ('тощая', 'NNP'),
#  ('труба', 'NNP'),
#  ('с', 'NNP'),
# ...

# %%
# Стемминг russian
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(word) for word in tokenized]
stemmed
# Out:
# ['виктор',
#  'петрович',
#  'астаф',
#  'перева',
#  'светл',
#  'памят',
#  'матер',
#  'мо',
#  'лид',
#  'ильиничн',
#  'далек',
#  'поселок',
#  'по',
#  'все',
#  'стран',
#  'стуча',
#  'звонк',
#  'топор',
#  '.',
#  'росс',
#  'стро',
#  'и',
#  'обновля',
#  '.',
#  'в',
#  'больш',
#  'сибирск',
#  'город',
#  ',',
#  'чут',
#  'повыш',
#  'стар',
#  'железнодорожн',
#  'мост',
#  ',',
#  'на',
#  'берег',
#  'енисе',
#  ',',
#  'как-т',
#  'раз',
#  ',',
#  'вдруг',
#  'подня',
#  'тощ',
#  'труб',
#  'с',
#  'искрогасител',
#  'и',
#  'нача',
#  'обильн',
#  'окурива',
#  'неб',
#  'едуч',
#  'опилочн',
#  'дым',
#  ',',
#  'зде',
#  'воздвига',
#  'и',
#  'быстр',
#  'рос',
#  'деревообделочн',
#  'комбинат',
#  '—',
#  'сокращен',
#  'док',
#  '.',
#  'сам',
#  'соб',
#  ',',
#  'комбинат',
#  ',',
#  'да',
#  'ещ',
#  'деревообделочн',
#  ',',
#  'требова',
#  'и',
#  'требова',
#  'лес',
#  '.',
#  'и',
#  'вот',
#  'двинул',
#  'в',
#  'таежн',
#  'кра',
#  ',',
# ...

# %%
import pymorphy3
morph = pymorphy3.MorphAnalyzer()
